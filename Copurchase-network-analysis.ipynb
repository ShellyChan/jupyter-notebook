# %% [markdown]
# ## Book Copurchase Graph Analysis

# %% [markdown]
# #### Table of Contents

# %% [markdown]
# * Introduction
# * Data Import and Formatting
# * Data Exploration
# * Graph Processing and Analysis

# %% [markdown]
# ### Imports

# %%
import cudf
import cugraph
import pandas as pd

# %% [markdown]
# ### Introduction to Dataset

# %% [markdown]
# Dataset is the processed version of Amazon Product co-purchasing network metadata taken from SNAP http://snap.stanford.edu/data/amazon-meta.html.
# The original dataset includes about 548,552 different products (Books, music CDs, DVDs, and VHS video tapes)
# The dataset used below is the filtered version of the above data which includes only Book Product.

# %% [markdown]
# ### Load and Explore Dataset

# %%
dataset_path = '../data/amazon/books/amazon-books.csv'

# %%
# %%time
gdf = cudf.DataFrame()
gdf = cudf.read_csv(dataset_path)
# Out:
# CPU times: user 439 ms, sys: 456 ms, total: 895 ms
# Wall time: 1.26 s

# %% [markdown]
# ### Exploration

# %% [markdown]
# Let's see how the data looks like.
# ASIN is the identifier for Amazon Book. Copurchased column contains a list of books that are commmonly purchased along with the book in ASIN column. These Copurchased data are collected from the Amazon Recommendation section "Customers who bought this item also bought".

# %%
# %%time
gdf.head().to_pandas()
# Out:
# CPU times: user 190 ms, sys: 25.3 ms, total: 215 ms
# Wall time: 214 ms
#    Id        ASIN                                              Title  \
# 0   1  0827229534            Patterns of Preaching: A Sermon Sampler
# 1   2  0738700797                         Candlemas: Feast of Flames
# 2   3  0486287785   World War II Allied Fighter Planes Trading Cards
# 3   4  0842328327  Life Application Bible Commentary: 1 and 2 Tim...
# 4   5  1577943082    Prayers That Avail Much for Business: Executive
#
#                                           Categories Group  \
# 0  subjects religion preaching clergy spiritualit...  Book
# 1  subjects witchcraft earth religion based spiri...  Book
# 2  general subjects hobbies home garden crafts books  Book
# 3  subjects life bibles christian general history...  Book
# 4  subjects religion prayerbooks devotion worship...  Book
#
#                                          Copurchased  SalesRank  TotalReviews  \
# 0  0804215715 156101074X 0687023955 0687074231 08...     396585             2
# 1  0738700827 1567184960 1567182836 0738700525 07...     168596            12
# 2                                               None    1270652             1
# 3        0842328130 0842330313 0842328610 0842328572     631289             1
# 4        157794349X 0892749504 1577941829 0892749563     455160             0
#
#    AvgRating
# 0        2.0
# 1       12.0
# 2        1.0
# 3        1.0
# 4        0.0

# %% [markdown]
# Notice that some of the copurchased data for the respective books are missing ("None"). Let's find out how many of them are missing.

# %%
# dataset contains 392966 rows.
# %time gdf.shape
# Out:
# CPU times: user 4 µs, sys: 4 µs, total: 8 µs
# Wall time: 11.7 µs
# (392966, 9)

# %%
# And all the books are unique
# %time gdf.ASIN.unique().shape[0]
# Out:
# CPU times: user 11 ms, sys: 19.1 ms, total: 30 ms
# Wall time: 30.2 ms
# 392966

# %%
# %%time
# Fill None with empty string for Object Type Columns.
gdf['Copurchased'] = gdf['Copurchased'].fillna('')
gdf['Categories'] = gdf['Categories'].fillna('')
# Out:
# CPU times: user 20.3 ms, sys: 8.23 ms, total: 28.5 ms
# Wall time: 80 ms

# %%
# There are 126553 records, 32% of the data are missing Copurchased info.
# %time gdf[gdf.Copurchased == ''].shape[0] / gdf.shape[0]
# Out:
# CPU times: user 883 ms, sys: 245 ms, total: 1.13 s
# Wall time: 1.2 s
# 0.32204567316256366

# %% [markdown]
# These missing Copurchased records are not gonna help us in finding which books are most similar to them. So we will reduce the number of book records.

# %%
# %time reduced_gdf = gdf[gdf.Copurchased != '']
# Out:
# CPU times: user 59.4 ms, sys: 139 ms, total: 198 ms
# Wall time: 295 ms

# %%
# %time reduced_gdf.shape[0]
# Out:
# CPU times: user 4 µs, sys: 4 µs, total: 8 µs
# Wall time: 10.5 µs
# 266413

# %% [markdown]
# ### Preprocessing for Graph Edgelist

# %% [markdown]
# Convert cudf to Pandas to use the Pandas APIs needed to split (explode) a column into multiple rows

# %%
# %time pd_df = reduced_gdf.to_pandas()
# Out:
# CPU times: user 288 ms, sys: 179 ms, total: 467 ms
# Wall time: 577 ms

# %%
# %time pd_df.head(2)
# Out:
# CPU times: user 1.62 ms, sys: 0 ns, total: 1.62 ms
# Wall time: 1.13 ms
#    Id        ASIN                                    Title  \
# 0   1  0827229534  Patterns of Preaching: A Sermon Sampler
# 1   2  0738700797               Candlemas: Feast of Flames
#
#                                           Categories Group  \
# 0  subjects religion preaching clergy spiritualit...  Book
# 1  subjects witchcraft earth religion based spiri...  Book
#
#                                          Copurchased  SalesRank  TotalReviews  \
# 0  0804215715 156101074X 0687023955 0687074231 08...     396585             2
# 1  0738700827 1567184960 1567182836 0738700525 07...     168596            12
#
#    AvgRating
# 0        2.0
# 1       12.0

# %% [markdown]
# Create new dataframe, splitting books in Copurchased into individual rows with ASIN as the index

# %%
# %time new_pd_df = pd.DataFrame(pd_df.Copurchased.str.split(' ').tolist(), index=pd_df.ASIN).stack()
# Out:
# CPU times: user 799 ms, sys: 51.6 ms, total: 850 ms
# Wall time: 849 ms

# %%
# %time new_pd_df.head(6)
# Out:
# CPU times: user 385 µs, sys: 0 ns, total: 385 µs
# Wall time: 390 µs
# ASIN
# 0827229534  0    0804215715
#             1    156101074X
#             2    0687023955
#             3    0687074231
#             4    082721619X
# 0738700797  0    0738700827
# dtype: object

# %%
# get rid of secondary index
# make ASIN as a column (it can't be an index since the values will be duplicate)
# %time new_pd_df = new_pd_df.reset_index([0, 'ASIN'])
# Out:
# CPU times: user 35 ms, sys: 0 ns, total: 35 ms
# Wall time: 34.5 ms

# %%
# %time new_pd_df.head(2)
# Out:
# CPU times: user 404 µs, sys: 238 µs, total: 642 µs
# Wall time: 538 µs
#          ASIN           0
# 0  0827229534  0804215715
# 1  0827229534  156101074X

# %%
# to save memory, select only the columns we need for our graph
# rename column '0' to column 'Copurchase_ASIN'
# %time new_pd_df.columns = ['ASIN', 'Copurchased_ASIN']
# Out:
# CPU times: user 336 µs, sys: 198 µs, total: 534 µs
# Wall time: 387 µs

# %%
# %time new_pd_df.head(2)
# Out:
# CPU times: user 512 µs, sys: 0 ns, total: 512 µs
# Wall time: 453 µs
#          ASIN Copurchased_ASIN
# 0  0827229534       0804215715
# 1  0827229534       156101074X

# %%
# %%time
new_gdf = cudf.from_pandas(new_pd_df)
# Out:
# CPU times: user 97.6 ms, sys: 65 ms, total: 163 ms
# Wall time: 169 ms

# %%
# %%time
# Merge exploded rows of Copurchased into original dataset.
combined_gdf = cudf.merge(new_gdf, gdf, on=['ASIN']).sort_values(['ASIN'])
# Out:
# CPU times: user 296 ms, sys: 371 ms, total: 667 ms
# Wall time: 868 ms

# %%
# %%time
combined_gdf.head(3).to_pandas()
# Out:
# CPU times: user 20.2 ms, sys: 0 ns, total: 20.2 ms
# Wall time: 19.1 ms
#               ASIN Copurchased_ASIN      Id              Title  \
# 432481  0001047655       0061099341  271961  Prodigal Daughter
# 432485  0001047655       0061007161  271961  Prodigal Daughter
# 432502  0001047655       0061007129  271961  Prodigal Daughter
#
#                                                Categories Group  \
# 432481  general tape subjects literature contemporary ...  Book
# 432485  general tape subjects literature contemporary ...  Book
# 432502  general tape subjects literature contemporary ...  Book
#
#                                               Copurchased  SalesRank  \
# 432481  0061007129 0061007358 0061007137 0061099341 00...    1116690
# 432485  0061007129 0061007358 0061007137 0061099341 00...    1116690
# 432502  0061007129 0061007358 0061007137 0061099341 00...    1116690
#
#         TotalReviews  AvgRating
# 432481            30       30.0
# 432485            30       30.0
# 432502            30       30.0

# %% [markdown]
# Remove Copurchased Columns which is redundant.

# %%
# %%time
combined_gdf = combined_gdf.drop('Copurchased')
combined_gdf = combined_gdf.drop('Group')
# Out:
# CPU times: user 16 ms, sys: 20 ms, total: 36.1 ms
# Wall time: 35.1 ms

# %% [markdown]
# ### Unipartite Correlation Network

# %% [markdown]
# We will form a Unipartite Graph between ASIN and Copurchased_ASIN. Based on the cuGraph requirements, we have to convert the aforementioned columns' Object Datatype to int32 type and vertex ids have to start from 0. So we will be creating columns of renumbered source vertex ids and destination vertex ids, both will be in int32 type. The numbering map from renumbering will map the new ids to original ids. The current renumbering API from cuGraph only support int32 type.

# %%
# %%time
combined_gdf.dtypes
# Out:
# CPU times: user 306 µs, sys: 194 µs, total: 500 µs
# Wall time: 506 µs
# ASIN                 object
# Copurchased_ASIN     object
# Id                    int64
# Title                object
# Categories           object
# SalesRank             int64
# TotalReviews          int64
# AvgRating           float64
# dtype: object

# %%
# %%time
combined_gdf.add_column('ASIN_int', combined_gdf['ASIN'].astype('int32'))
combined_gdf.add_column('Copurchased_ASIN_int', combined_gdf['Copurchased_ASIN'].astype('int32'))
# Out:
# CPU times: user 8.17 ms, sys: 82 µs, total: 8.25 ms
# Wall time: 43.6 ms

# %%
# %%time
G = cugraph.Graph()

# The cugraph renumbering feature allows us to take two columns of any integer type and translate them 
# into a densely packed contiguous array numbered from 0 to (num_unique_values - 1).
# These renumbered vertices can be used to create a graph much more efficiently.

src_r, dst_r, numbering = G.renumber(combined_gdf['ASIN_int'], combined_gdf['Copurchased_ASIN_int'])
# Out:
# CPU times: user 7.01 ms, sys: 2.78 ms, total: 9.79 ms
# Wall time: 14.5 ms

# %%
# %%time
combined_gdf.add_column("src_id", src_r)
combined_gdf.add_column("dst_id", dst_r)
# Out:
# CPU times: user 78 µs, sys: 50 µs, total: 128 µs
# Wall time: 133 µs

# %%
numbering.head(4).to_pandas()
# Out:
# 0     60621591
# 1     62505521
# 2     76790625
# 3    152008578
# dtype: int32

# %% [markdown]
# Explore by querying an original dataframe for book title or ASIN.

# %%
# %%time
query_range = combined_gdf[combined_gdf.SalesRank > 0]
# Out:
# CPU times: user 193 ms, sys: 244 ms, total: 438 ms
# Wall time: 651 ms

# %%
query_range[query_range.SalesRank < 200].sort_values('SalesRank', ascending=True).to_pandas()
# Out:
#               ASIN Copurchased_ASIN      Id  \
# 42690   0385504209       0440136482     296
# 42712   0385504209       0671027360     296
# 42716   0385504209       0671027387     296
# 686839  0385730586       0385729340  390452
# 686843  0385730586       037582233X  390452
# 686847  0385730586       0609807900  390452
# 197515  0316346624       0066620996   89000
# 549475  0142001740       0156027321  337971
# 227168  0066620996       0060516402  154855
# 227172  0066620996       0609610570  154855
# 227176  0066620996       0684852861  154855
# 227180  0066620996       0316346624  154855
# 598759  0671027360       0385504209  376858
# 598763  0671027360       0671027387  376858
# 598767  0671027360       0440136482  376858
# 520035  0310205719       0966089529  312527
# 520061  0310205719       0966089510  312527
# 243777  0446677450       0446677469  162283
# 243781  0446677450       0446678619  162283
# 243785  0446677450       0449214923  162283
# 243789  0446677450       0446678430  162283
# 243806  0446677450       0446677477  162283
# 78926   0156027321       0142001740   62424
# 78930   0156027321       0312422156   62424
# 787411  0743201140       0684852861  448350
# 787415  0743201140       0066620996  448350
# 787419  0743201140       0787960756  448350
# 144675  0316769487       0451524934   98756
# 144689  0316769487       0446310786   98756
# 144693  0316769487       0684801523   98756
# ...            ...              ...     ...
# 616963  0671524313       0789205386  364022
# 616967  0671524313       0761121323  364022
# 616971  0671524313       0761521674  364022
# 616975  0671524313       0399523308  364022
# 645836  0316778001       0071381392  378941
# 645840  0316778001       0316779245  378941
# 645844  0316778001       0316778095  378941
# 25414   006441034X       0064473457   24221
# 25418   006441034X       006447268X   24221
# 25422   006441034X       0064472698   24221
# 828818  0887307280       0887309593  511268
# 828822  0887307280       0060938463  511268
# 828826  0887307280       0967029104  511268
# 859777  0226104036       0520218353  520843
# 859806  0226104036       020530902X  520843
# 261166  0385474547       0764586475  158148
# 261170  0385474547       0486264645  158148
# 261174  0385474547       0553272535  158148
# 261178  0385474547       0385474555  158148
# 261182  0385474547       0878912339  158148
# 470121  0684833395       0440180295  288563
# 470125  0684833395       0316769487  288563
# 470129  0684833395       0451524934  288563
# 470133  0684833395       0060929871  288563
# 470137  0684833395       0345342968  288563
# 372353  0446677477       0446677469  223997
# 372357  0446677477       0446678619  223997
# 372361  0446677477       0446678430  223997
# 372365  0446677477       0446530867  223997
# 372382  0446677477       0446677450  223997
#
#                                                     Title  \
# 42690                                   The Da Vinci Code
# 42712                                   The Da Vinci Code
# 42716                                   The Da Vinci Code
# 686839  Sisterhood of the Traveling Pants (Sisterhood ...
# 686843  Sisterhood of the Traveling Pants (Sisterhood ...
# 686847  Sisterhood of the Traveling Pants (Sisterhood ...
# 197515  The Tipping Point: How Little Things Can Make ...
# 549475                            The Secret Life of Bees
# 227168  Good to Great: Why Some Companies Make the Lea...
# 227172  Good to Great: Why Some Companies Make the Lea...
# 227176  Good to Great: Why Some Companies Make the Lea...
# 144693          2568     2568.0  316769487             684801523  235008
# ...              ...        ...        ...                   ...     ...
# 616963           785      785.0  671524313             789205386   50124
# 616967           785      785.0  671524313             761121323   50124
# 616971           785      785.0  671524313             761521674   50124
# 616975           785      785.0  671524313             399523308   50124
# 645836           548      548.0  316778001              71381392  245554
# 645840           548      548.0  316778001             316779245  245554
# 645844           548      548.0  316778001             316778095  245554
# 25414            104      104.0    6441034              64473457   94891
# 25418            104      104.0    6441034               6447268   94891
# 25422            104      104.0    6441034              64472698   94891
# 828818           137      137.0  887307280             887309593   26551
# 828822           137      137.0  887307280              60938463   26551
# 828826           137      137.0  887307280             967029104   26551
# 859777            21       21.0  226104036             520218353  259123
# 859806            21       21.0  226104036              20530902  259123
# 261166           408      408.0  385474547             764586475  200628
# 261170           408      408.0  385474547             486264645  200628
# 261174           408      408.0  385474547             553272535  200628
# 261178           408      408.0  385474547             385474555  200628
# 261182           408      408.0  385474547             878912339  200628
# 470121           732      732.0  684833395             440180295    8669
# 470125           732      732.0  684833395             316769487    8669
# 470129           732      732.0  684833395             451524934    8669
# 470133           732      732.0  684833395              60929871    8669
# 470137           732      732.0  684833395             345342968    8669
# 372353           224      224.0  446677477             446677469  193332
# 372357           224      224.0  446677477             446678619  193332
# 372361           224      224.0  446677477             446678430  193332
# 372365           224      224.0  446677477             446530867  193332
# 372382           224      224.0  446677477             446677450  193332
#
#         dst_id
# 42690    41363
# 42712   140367
# 42716   141277
# 686839  229112
# 686843   61985
# 686847  142910
# 197515  118003
# 549475  170028
# 227168   41514
# 227172  117789
# 227176  109719
# 227180   64862
# 598759   97478
# 598763  141277
# 598767   41363
# 520035   65537
# 520061   64942
# 243777  193062
# 243781  230748
# 243785  135102
# 243789  224391
# 243806  193332
# 78926    83262
# 78930    33185
# 787411  109719
# 787415  118003
# 787419   95943
# 144675  140072
# 144689  255950
# 144693   37149
# ...        ...
# 616963   82296
# 616967  178483
# 616971  145343
# 616975  239806
# 645836  165608
# 645840   16541
# 645844  248720
# 25414    67634
# 25418    30551
# 25422    42839
# 828818  102600
# 828822  185031
# 828826  258238
# 859777  261787
# 859806  140278
# 261166  190181
# 261170  195490
# 261174  106259
# 261178  200899
# 261182   53414
# 470121  136557
# 470125  235008
# 470129  140072
# 470133  171950
# 470137   71687
# 372353  193062
# 372357  230748
# 372361  224391
# 372365  220292
# 372382  192426
#
# [257 rows x 12 columns]

# %% [markdown]
# Create a Directed Graph of a copurchase network. Edges are pointing from one book to another.

# %%
G.add_edge_list(combined_gdf["src_id"], combined_gdf["dst_id"])

# %%
G.number_of_edges()
# Out:
# 910848

# %%
G.number_of_vertices()
# Out:
# 270038

# %%
degree = G.degree()
in_degree = G.in_degree()
out_degree = G.out_degree()

# %% [markdown]
# We get the edge lists for the two-hop neighbors. (traverse two hops, starting node is first and after two hops, the end node is second) start->hop->end

# %%
two_hop = G.get_two_hop_neighbors()
two_hop
# Out:
# <cudf.DataFrame ncols=2 nrows=2170614 >

# %%
two_hop[two_hop.first==0].to_pandas()
# Out:
#    first  second
# 0      0    9307
# 1      0   21939
# 2      0  106041
# 3      0  146031
# 4      0  150209
# 5      0  234029

# %%
combined_gdf[combined_gdf.ASIN == '0890420254'].to_pandas()
# Out:
#               ASIN Copurchased_ASIN      Id  \
# 752320  0890420254       0898625688  458358
# 752324  0890420254       0890420262  458358
# 753495  0890420254       0890420270  458358
# 753499  0890420254       0963382136  458358
# 753503  0890420254       1585620599  458358
#
#                                                     Title  \
# 752320  Diagnostic and Statistical Manual of Mental Di...
# 752324  Diagnostic and Statistical Manual of Mental Di...
# 753495  Diagnostic and Statistical Manual of Mental Di...
# 753499  Diagnostic and Statistical Manual of Mental Di...
# 753503  Diagnostic and Statistical Manual of Mental Di...
#
#                                                Categories  SalesRank  \
# 752320  body reference general medicine subjects medic...        371
# 752324  body reference general medicine subjects medic...        371
# 753495  body reference general medicine subjects medic...        371
# 753499  body reference general medicine subjects medic...        371
# 753503  body reference general medicine subjects medic...        371
#
#         TotalReviews  AvgRating   ASIN_int  Copurchased_ASIN_int  src_id  \
# 752320            35       35.0  890420254             898625688   39084
# 752324            35       35.0  890420254             890420262   39084
# 753495            35       35.0  890420254             890420270   39084
# 753499            35       35.0  890420254             963382136   39084
# 753503            35       35.0  890420254            1585620599   39084
#
#         dst_id
# 752320  245652
# 752324   39364
# 753495   39625
# 753499  193262
# 753503  224448

# %%
ASIN = '0890420254'
ASIN_int = 890420254
book_1 = numbering[numbering == ASIN_int].index[0]
book_1
# Out:
# 39084

# %%
# %%time
clist = cudf.DataFrame()
clist["second"] = two_hop.second.unique().astype("int32")
# Out:
# CPU times: user 217 ms, sys: 27.8 ms, total: 245 ms
# Wall time: 244 ms

# %%
# %%time
clist["first"] = book_1.astype("int32")
# Out:
# CPU times: user 159 ms, sys: 6.85 ms, total: 166 ms
# Wall time: 164 ms

# %%
# %%time
degree_query = degree[degree.vertex == book_1]
in_degree_query = in_degree[in_degree.vertex == book_1]
out_degree_query = out_degree[out_degree.vertex == book_1]
# Out:
# CPU times: user 46.8 ms, sys: 36.3 ms, total: 83.1 ms
# Wall time: 146 ms

# %%
degree_query.to_pandas()
# Out:
#        vertex  degree
# 39084   39084     329

# %% [markdown]
# book_1 has more incoming edges than outgoing ones. That means through the purchase of connected neighbor books, people discover book_1 and purchased it, and that's why the Sales Ranking for book_1 is high as well.

# %%
in_degree_query.to_pandas()
# Out:
#        vertex  degree
# 39084   39084     324

# %%
out_degree_query.to_pandas()
# Out:
#        vertex  degree
# 39084   39084       5

# %% [markdown]
# The Jaccard similarity between two sets is defined as the ratio of the volume of their intersection divided by the volume of their union.
#
# The Jaccard Similarity can then be defined as
#
# <a href="https://www.codecogs.com/eqnedit.php?latex=js(A,B)&space;=&space;\frac{|A&space;\cap&space;B|}{|A&space;\cup&space;B&space;|&space;}&space;=&space;\frac{|A&space;\cap&space;B|}{&space;|A|&space;&plus;&space;|B|&space;-&space;|A&space;\cup&space;B&space;|&space;}" target="_blank"><img src="https://latex.codecogs.com/gif.latex?js(A,B)&space;=&space;\frac{|A&space;\cap&space;B|}{|A&space;\cup&space;B&space;|&space;}&space;=&space;\frac{|A&space;\cap&space;B|}{&space;|A|&space;&plus;&space;|B|&space;-&space;|A&space;\cup&space;B&space;|&space;}" title="js(A,B) = \frac{|A \cap B|}{|A \cup B | } = \frac{|A \cap B|}{ |A| + |B| - |A \cup B | }" /></a>

# %% [markdown]
# cuGraph's Jaccard computation allows us to pass a list of src/dst vertices to compute, so that we don't have to compute all possible combinations.
# We try to find what are the other books similar to book_1 using Jaccard Similarity.

# %%
# %%time
jacc_clist_1 = cugraph.jaccard(G, first=clist.first, second=clist.second)
# Out:
# CPU times: user 116 ms, sys: 3.51 ms, total: 120 ms
# Wall time: 118 ms

# %%
# %%time
jacc_clist_1.sort_values("jaccard_coeff", ascending=False).head(25).to_pandas()
# Out:
# CPU times: user 19.3 ms, sys: 7.5 ms, total: 26.8 ms
# Wall time: 81.3 ms
#         source  destination  jaccard_coeff
# 20927    39084        39084       1.000000
# 21068    39084        39364       0.428571
# 21213    39084        39625       0.428571
# 118356   39084       220121       0.428571
# 106142   39084       197246       0.333333
# 76603    39084       142630       0.285714
# 119188   39084       221679       0.285714
# 132283   39084       245951       0.285714
# 11607    39084        21752       0.250000
# 103976   39084       193262       0.250000
# 119946   39084       223047       0.250000
# 120699   39084       224448       0.250000
# 132117   39084       245652       0.250000
# 61415    39084       114215       0.166667
# 132224   39084       245829       0.166667
# 137203   39084       254982       0.166667
# 50841    39084        94527       0.142857
# 59557    39084       110748       0.142857
# 79042    39084       147157       0.142857
# 132643   39084       246611       0.142857
# 6901     39084        13078       0.125000
# 16607    39084        31096       0.125000
# 20460    39084        38194       0.125000
# 23836    39084        44448       0.125000
# 28427    39084        53044       0.125000

# %%
# %%time
combined_gdf[combined_gdf.ASIN_int == numbering[book_1]].to_pandas()
# Out:
# CPU times: user 26.1 ms, sys: 53.6 ms, total: 79.8 ms
# Wall time: 146 ms
#               ASIN Copurchased_ASIN      Id  \
# 752320  0890420254       0898625688  458358
# 752324  0890420254       0890420262  458358
# 753495  0890420254       0890420270  458358
# 753499  0890420254       0963382136  458358
# 753503  0890420254       1585620599  458358
#
#                                                     Title  \
# 752320  Diagnostic and Statistical Manual of Mental Di...
# 752324  Diagnostic and Statistical Manual of Mental Di...
# 753495  Diagnostic and Statistical Manual of Mental Di...
# 753499  Diagnostic and Statistical Manual of Mental Di...
# 753503  Diagnostic and Statistical Manual of Mental Di...
#
#                                                Categories  SalesRank  \
# 752320  body reference general medicine subjects medic...        371
# 752324  body reference general medicine subjects medic...        371
# 753495  body reference general medicine subjects medic...        371
# 753499  body reference general medicine subjects medic...        371
# 753503  body reference general medicine subjects medic...        371
#
#         TotalReviews  AvgRating   ASIN_int  Copurchased_ASIN_int  src_id  \
# 752320            35       35.0  890420254             898625688   39084
# 752324            35       35.0  890420254             890420262   39084
# 753495            35       35.0  890420254             890420270   39084
# 753499            35       35.0  890420254             963382136   39084
# 753503            35       35.0  890420254            1585620599   39084
#
#         dst_id
# 752320  245652
# 752324   39364
# 753495   39625
# 753499  193262
# 753503  224448
