# %% [markdown]
# ## Amazon Book Recommendation

# %% [markdown]
# #### Table of Contents

# %% [markdown]
# * Introduction
# * Data Imported and Formatting
# * Data Exploration
# * Graph Processing and Analysis

# %% [markdown]
# ### Imports

# %%
import cudf
import cugraph
import numpy as np

import pandas as pd
import string
import nvstrings, nvtext
try:
    import nltk
except ModuleNotFoundError:
    os.system('pip install nltk')
    import nltk
    nltk.download('stopwords')

from collections import OrderedDict

# %% [markdown]
# ### Introduction

# %% [markdown]
# Dataset is the processed version of Amazon Product co-purchasing network metadata taken from SNAP http://snap.stanford.edu/data/amazon-meta.html.
# The original dataset includes about 548,552 different products (Books, music CDs, DVDs, and VHS video tapes)
# The dataset used below includes only Book.

# %% [markdown]
# ### Load and Explore Dataset

# %%
dataset_path = '../data/amazon/books/amazon-books.csv'

# %%
# %%time
gdf = cudf.DataFrame()
gdf = cudf.read_csv(dataset_path)
# Out:
# CPU times: user 128 ms, sys: 132 ms, total: 261 ms
# Wall time: 264 ms

# %%
# %%time
gdf.head().to_pandas()
# Out:
# CPU times: user 22 ms, sys: 779 µs, total: 22.8 ms
# Wall time: 21.5 ms
#    Id        ASIN                                              Title  \
# 0   1  0827229534            Patterns of Preaching: A Sermon Sampler
# 1   2  0738700797                         Candlemas: Feast of Flames
# 2   3  0486287785   World War II Allied Fighter Planes Trading Cards
# 3   4  0842328327  Life Application Bible Commentary: 1 and 2 Tim...
# 4   5  1577943082    Prayers That Avail Much for Business: Executive
#
#                                           Categories Group  \
# 0  subjects religion preaching clergy spiritualit...  Book
# 1  subjects witchcraft earth religion based spiri...  Book
# 2  general subjects hobbies home garden crafts books  Book
# 3  subjects life bibles christian general history...  Book
# 4  subjects religion prayerbooks devotion worship...  Book
#
#                                          Copurchased  SalesRank  TotalReviews  \
# 0  0804215715 156101074X 0687023955 0687074231 08...     396585             2
# 1  0738700827 1567184960 1567182836 0738700525 07...     168596            12
# 2                                               None    1270652             1
# 3        0842328130 0842330313 0842328610 0842328572     631289             1
# 4        157794349X 0892749504 1577941829 0892749563     455160             0
#
#    AvgRating
# 0        2.0
# 1       12.0
# 2        1.0
# 3        1.0
# 4        0.0

# %% [markdown]
# #### Explore Books

# %% [markdown]
# Dataset contains 393535 book titles.

# %%
# %%time
gdf.shape
# Out:
# CPU times: user 8 µs, sys: 4 µs, total: 12 µs
# Wall time: 16.2 µs
# (392966, 9)

# %%
# %%time
gdf.ASIN.unique().shape[0]
# Out:
# CPU times: user 4.6 ms, sys: 24.3 ms, total: 28.9 ms
# Wall time: 27.6 ms
# 392966

# %%
# %%time
query = gdf[gdf.ASIN == "1577943082"]
print(query)
# Out:
#    Id        ASIN                                            Title                                                                                                Categories  Group                                  Copurchased  SalesRank ...  AvgRating
# 4   5  1577943082  Prayers That Avail Much for Business: Executive  subjects religion prayerbooks devotion worship business spirituality living books christianity christian   Book  157794349X 0892749504 1577941829 0892749563     455160 ...        0.0
# [1 more columns]
# CPU times: user 166 ms, sys: 125 ms, total: 291 ms
# Wall time: 296 ms

# %% [markdown]
# #### Preprocessing

# %%
# convert cudf to pandas since the APIs needed to split (explode) a column into multiple rows is not supported yet
pd_df = gdf.to_pandas()

# %%
pd_df.Copurchased = pd_df.Copurchased.fillna('').astype(str)

# %%
pd_df.head(6)
# Out:
#    Id        ASIN                                              Title  \
# 0   1  0827229534            Patterns of Preaching: A Sermon Sampler
# 1   2  0738700797                         Candlemas: Feast of Flames
# 2   3  0486287785   World War II Allied Fighter Planes Trading Cards
# 3   4  0842328327  Life Application Bible Commentary: 1 and 2 Tim...
# 4   5  1577943082    Prayers That Avail Much for Business: Executive
# 5   6  0486220125  How the Other Half Lives: Studies Among the Te...
#
#                                           Categories Group  \
# 0  subjects religion preaching clergy spiritualit...  Book
# 1  subjects witchcraft earth religion based spiri...  Book
# 2  general subjects hobbies home garden crafts books  Book
# 3  subjects life bibles christian general history...  Book
# 4  subjects religion prayerbooks devotion worship...  Book
# 5  general social subjects history jewish nonfict...  Book
#
#                                          Copurchased  SalesRank  TotalReviews  \
# 0  0804215715 156101074X 0687023955 0687074231 08...     396585             2
# 1  0738700827 1567184960 1567182836 0738700525 07...     168596            12
# 2                                                       1270652             1
# 3        0842328130 0842330313 0842328610 0842328572     631289             1
# 4        157794349X 0892749504 1577941829 0892749563     455160             0
# 5        0486401960 0452283612 0486229076 0714840343     188784            17
#
#    AvgRating
# 0        2.0
# 1       12.0
# 2        1.0
# 3        1.0
# 4        0.0
# 5       17.0

# %%
# create new dataframe from the series with ASIN as the index
new_pd_df = pd.DataFrame(pd_df.Copurchased.str.split(' ').tolist(), index=pd_df.ASIN).stack()

# %%
new_pd_df.head(6)
# Out:
# ASIN
# 0827229534  0    0804215715
#             1    156101074X
#             2    0687023955
#             3    0687074231
#             4    082721619X
# 0738700797  0    0738700827
# dtype: object

# %%
# get rid of secondary index
# make ASIN as a column (it can't be an index since the values will be duplicate)
new_pd_df = new_pd_df.reset_index([0, 'ASIN'])

# %%
# to save memory, select only the columns we need for our graph
# ASIN will become our nodes
new_pd_df.columns = ['ASIN', 'Copurchase_ASIN']

# %%
new_pd_df.head(10)
# Out:
#          ASIN Copurchase_ASIN
# 0  0827229534      0804215715
# 1  0827229534      156101074X
# 2  0827229534      0687023955
# 3  0827229534      0687074231
# 4  0827229534      082721619X
# 5  0738700797      0738700827
# 6  0738700797      1567184960
# 7  0738700797      1567182836
# 8  0738700797      0738700525
# 9  0738700797      0738700940

# %%
# %%time
sorted_pd_df = new_pd_df.sort_values(by=['ASIN'])
# Out:
# CPU times: user 1.59 s, sys: 1.26 ms, total: 1.59 s
# Wall time: 1.59 s

# %%
sorted_pd_df
# Out:
#               ASIN Copurchase_ASIN
# 700446  0000037931
# 511570  0001047655      0061007358
# 511569  0001047655      0061007129
# 511571  0001047655      0061007137
# 511572  0001047655      0061099341
# 511573  0001047655      0061007161
# 886962  0001053388
# 596758  0001053736      0345336062
# 596759  0001053736      0140380531
# 596757  0001053736      0440905605
# 596760  0001053736      0393320979
# 596761  0001053736      0395898714
# 735765  0001053744
# 215665  0001054600
# 683314  0001056298
# 926560  000105709X
# 21250   0001057170      1585673080
# 308118  0001360817
# 168445  0001360841
# 328483  0001360876
# 820167  0001360922
# 482249  0001360965
# 298638  0001469355
# 261472  0001472933      0895403889
# 235146  0001473816
# 2018    0001474103      0001472933
# 2017    0001474103      0895403889
# 180751  0001515195      0005310075
# 180750  0001515195      0875525660
# 91887   0001526626
# ...            ...             ...
# 973798  9999752969
# 299524  9999753256
# 517666  9999766927
# 685337  9999767036
# 466670  9999767044
# 583981  9999767125
# 330349  9999770541
# 388545  9999794971
# 730326  9999803938      091152147X
# 730327  9999803938      088011701X
# 574512  9999804136
# 914641  9999815286
# 612179  9999827659
# 660195  9999829503
# 661931  9999841651
# 317850  9999869491
# 484319  9999878172
# 161649  9999902979
# 869468  9999928498
# 389625  9999928501
# 464215  9999929257
# 599530  9999957501      1573921394
# 599529  9999957501      0879757051
# 599528  9999957501      0553585975
# 599531  9999957501      0553212788
# 599527  9999957501      0451527100
# 861318  9999962017
# 582419  9999974856
# 502784  9999974872
# 350837  9999975380
#
# [1037401 rows x 2 columns]

# %% [markdown]
# Construct Book Graph

# %%
# %%time
graph_gdf = cudf.from_pandas(sorted_pd_df)
# Out:
# CPU times: user 304 ms, sys: 51.9 ms, total: 356 ms
# Wall time: 355 ms

# %%
graph_gdf
# Out:
# <cudf.DataFrame ncols=2 nrows=1037401 >

# %%
graph_gdf.dtypes
# Out:
# ASIN               object
# Copurchase_ASIN    object
# dtype: object

# %% [markdown]
# #### Graph Processing

# %% [markdown]
# convert to edge list format

# %%
#graph_gdf.ASIN = graph_gdf.ASIN.astype('int32')
#graph_gdf.Copurchase_ASIN = graph_gdf.Copurchase_ASIN.astype('int32')

# %%
graph_gdf.ASIN.shape[0]
# Out:
# 1037401

# %%
graph_gdf.Copurchase_ASIN.shape[0]
# Out:
# 1037401

# %%
#src_edges = cudf.concat([graph_gdf.ASIN]).reset_index()['ASIN']
#dest_edges = cudf.concat([graph_gdf.Copurchase_ASIN]).reset_index()['Copurchase_ASIN']
#weights = cudf.concat([cudf.Series(np.ones(graph_gdf.ASIN.shape[0]))])

# %%
#new_graph_gdf = cudf.DataFrame()
#new_graph_gdf["src"] = src_edges
#new_graph_gdf["dest"] = dest_edges
#new_graph_gdf["weights"] = weights

#new_graph_gdf.head(10).to_pandas()

# %%
# %%time
graph_gdf["src_id"], graph_gdf["dest_id"], numbering = cugraph.Graph().renumber(graph_gdf.ASIN, graph_gdf.Copurchase_ASIN)
# Out:
# CPU times: user 5.42 ms, sys: 4.48 ms, total: 9.9 ms
# Wall time: 9.76 ms

# %%
graph_gdf.to_pandas().sort_values(by=['src_id'])
# Out:
#                ASIN Copurchase_ASIN  src_id  dest_id
# 208371   007011496X                       1        0
# 234217   0060621591      0520222288       2   175960
# 234216   0060621591      0060556102       2     1768
# 300315   0062505521      1586210467       3   332369
# 300316   0062505521      0451527534       3   328301
# 300314   0062505521      0446676500       3   234316
# 300312   0062505521      0800634497       3   249409
# 300313   0062505521      0060646918       3    35350
# 1026993  076790625X      0743212754       4   111887
# 1026994  076790625X      0385231261       4    15976
# 1026992  076790625X      0878301224       4   233324
# 363842   097128878X                       5        0
# 436552   0152008578      0152015728       6   342810
# 436555   0152008578      156294729X       6   106553
# 436554   0152008578      0803721242       6   188171
# 436553   0152008578      0689807767       6   127968
# 436551   0152008578      0873587286       6    35378
# 830681   0156005786      0374527105       7    85274
# 830680   0156005786      0452272408       7   304319
# 830679   0156005786      9074597076       7    47411
# 768622   0262611651      0942299442       8   325998
# 768623   0262611651      0262681064       8   185548
# 768624   0262611651      0415939437       8    21472
# 768621   0262611651      0262610469       8   335977
# 660435   0446524174      0786865954       9   274864
# 660434   0446524174      0446527556       9   160988
# 660433   0446524174      0446520942       9   237757
# 965388   0486217760      0486235424      10    59929
# 965390   0486217760      0486222543      10   229276
# 965389   0486217760      0877731934      10    35473
# ...             ...             ...     ...      ...
# 800794   0873512812      087351162X  392954   110434
# 800793   0873512812      0816624283  392954   295256
# 135790   0874700507                  392955        0
# 560546   0882801406                  392956        0
# 623369   0883858045      0883858096  392957     2341
# 623370   0883858045      0817641556  392957   371483
# 531916   0892876336      1929133049  392958   245065
# 531915   0892876336      0760303703  392958   330286
# 688675   0932807461                  392959        0
# 74483    0969707916      0201407264  392960   333347
# 74481    0969707916      0969707983  392960     3090
# 74480    0969707916      0882681087  392960   120350
# 74482    0969707916      0399523863  392960   376008
# 80378    1556191707                  392961        0
# 1002266  1563891247      1563896168  392962   235940
# 1002267  1563891247      1563894831  392962   170920
# 1002268  1563891247      1563899736  392962    14032
# 1002269  1563891247      0930289455  392962   231117
# 889572   1566397693      0822325942  392963   329667
# 889573   1566397693      0786710292  392963   273283
# 889574   1566397693      087286412X  392963   148036
# 434341   1575841916                  392964        0
# 968814   1577193431                  392965        0
# 272694   1580625460      030717025X  392966    36354
# 57504    1586211722      0060523794  392967    23190
# 57503    1586211722      0071409378  392967    11359
# 57502    1586211722      0070581045  392967   354285
# 57505    1586211722      0786868414  392967   392952
# 950727   1588202135                  392968        0
# 437027   1894611063                  392969        0
#
# [1037401 rows x 4 columns]

# %% [markdown]
# Create a Graph

# %%
graph = cugraph.Graph()
graph.add_edge_list(graph_gdf["src_id"], graph_gdf["dest_id"])

# %%
graph.degree()
# Out:
# <cudf.DataFrame ncols=2 nrows=392970 >

# %%
graph.number_of_vertices()
# Out:
# 392970

# %%
# Call cugraph.pagerank to get the pagerank scores
cu_count = cugraph.triangles(graph)

# %%
cu_count
# Out:
# 610705

# %%
# %time jac_df = cugraph.jaccard(graph)
# Out:
# CPU times: user 8.43 ms, sys: 4.16 ms, total: 12.6 ms
# Wall time: 11.4 ms

# %%
jac_df.sort_values("source", ascending=False).head(25).to_pandas()
# Out:
#          source  destination  jaccard_coeff
# 1037400  392969            0       0.000000
# 1037399  392968            0       0.000000
# 1037395  392967        11359       0.166667
# 1037396  392967        23190       0.000000
# 1037397  392967       354285       0.166667
# 1037398  392967       392952       0.000000
# 1037394  392966        36354       0.000000
# 1037393  392965            0       0.000000
# 1037392  392964            0       0.000000
# 1037389  392963       148036       0.000000
# 1037390  392963       273283       0.000000
# 1037391  392963       329667       0.000000
# 1037385  392962        14032       0.142857
# 1037386  392962       170920       0.142857
# 1037387  392962       231117       0.000000
# 1037388  392962       235940       0.166667
# 1037384  392961            0       0.000000
# 1037380  392960         3090       0.166667
# 1037381  392960       120350       0.166667
# 1037382  392960       333347       0.142857
# 1037383  392960       376008       0.166667
# 1037379  392959            0       0.000000
# 1037377  392958       245065       0.250000
# 1037378  392958       330286       0.333333
# 1037375  392957         2341       0.000000

# %%
jac_df.sort_values("jaccard_coeff", ascending=False).head(25).to_pandas()
# Out:
#       source  destination  jaccard_coeff
# 936      364         1105            0.8
# 937      364        40906            0.8
# 938      364        41662            0.8
# 939      364       159142            0.8
# 940      364       160327            0.8
# 1689     650       228009            0.8
# 1879     725        48138            0.8
# 1880     725        75056            0.8
# 1882     725       241792            0.8
# 1980     763       105414            0.8
# 1983     763       210031            0.8
# 1995     767        43789            0.8
# 1997     767       209446            0.8
# 2873    1104       380263            0.8
# 3129    1193       130455            0.8
# 3149    1201        81226            0.8
# 3150    1201        88514            0.8
# 3152    1201       310789            0.8
# 3159    1205       233271            0.8
# 3614    1372        68186            0.8
# 3756    1428        46082            0.8
# 3760    1428       371882            0.8
# 3779    1435       294814            0.8
# 3804    1443       186270            0.8
# 3916    1480        46146            0.8

# %%
# define a function for printing the top most similar vertices
def print_most_similar_jaccard(df):
    
    jmax = df['jaccard_coeff'].max()
    dm = df.query('jaccard_coeff >= @jmax')    
    
    #find the best
    for i in range(len(dm)):    
        print("Vertices " + str(dm['source'][i]) + " and " + 
              str(dm['destination'][i]) + " are most similar with score: " 
              + str(dm['jaccard_coeff'][i]))
    del jmax
    del dm

# define a function for printing the top most similar vertices
def print_most_similar_overlap(df):
    
    smax = df['overlap_coeff'].max()
    dm = df.query('overlap_coeff >= @smax')      
    
    for i in range(len(dm)):
        print("Vertices " + str(dm['source'][i]) + " and " + 
          str(dm['destination'][i]) + " are most similar with score: " 
          + str(dm['overlap_coeff'][i]))
        
    del smax
    del dm

# %%
print_most_similar_jaccard(jac_df)

# %%
# numbering map that maps the new source ids to the original ASIN.
ASIN = numbering[1480]
ASIN
# Out:
# 914525182

# %%
print(graph_gdf[graph_gdf.source==364])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-151-f3384dc728a7> in <module>
# ----> 1 print(graph_gdf[graph_gdf.source==364])
#
# /conda/envs/rapids/lib/python3.6/site-packages/cudf/dataframe/dataframe.py in __getattr__(self, key)
#     221             return self[key]
#     222
# --> 223         raise AttributeError("'DataFrame' object has no attribute %r" % key)
#     224
#     225     def __getitem__(self, arg):
#
# AttributeError: 'DataFrame' object has no attribute 'source'
