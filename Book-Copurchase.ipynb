# %% [markdown]
# ## Book Copurchase Graph

# %% [markdown]
# #### Table of Contents

# %% [markdown]
# * Introduction
# * Data Imported and Formatting
# * Data Exploration
# * Graph Processing and Analysis

# %% [markdown]
# ### Imports

# %%
import cudf
import cugraph
import numpy as np

import pandas as pd

# %% [markdown]
# ### Introduction

# %% [markdown]
# Dataset is the processed version of Amazon Product co-purchasing network metadata taken from SNAP http://snap.stanford.edu/data/amazon-meta.html.
# The original dataset includes about 548,552 different products (Books, music CDs, DVDs, and VHS video tapes)
# The dataset used below includes only Book.

# %% [markdown]
# ### Load and Explore Dataset

# %%
dataset_path = '../data/amazon/books/amazon-books-v2.0.csv'

# %%
# %%time
gdf = cudf.DataFrame()
gdf = cudf.read_csv(dataset_path)
# Out:
# CPU times: user 113 ms, sys: 145 ms, total: 258 ms
# Wall time: 262 ms

# %% [markdown]
# To see how the data looks like

# %% [markdown]
# ASIN is the identifier for Amazon Book. Copurchased column contains a list of books that are normally purchased along with the book in ASIN column.

# %%
# %%time
gdf.head().to_pandas()
# Out:
# CPU times: user 22.3 ms, sys: 926 µs, total: 23.3 ms
# Wall time: 22 ms
#    Id        ASIN                                              Title  \
# 0   1  0827229534            Patterns of Preaching: A Sermon Sampler
# 1   2  0738700797                         Candlemas: Feast of Flames
# 2   3  0486287785   World War II Allied Fighter Planes Trading Cards
# 3   4  0842328327  Life Application Bible Commentary: 1 and 2 Tim...
# 4   5  1577943082    Prayers That Avail Much for Business: Executive
#
#                                           Categories Group  \
# 0  subjects religion preaching clergy spiritualit...  Book
# 1  subjects witchcraft earth religion based spiri...  Book
# 2  general subjects hobbies home garden crafts books  Book
# 3  subjects life bibles christian general history...  Book
# 4  subjects religion prayerbooks devotion worship...  Book
#
#                                          Copurchased  SalesRank  TotalReviews  \
# 0  0804215715 156101074X 0687023955 0687074231 08...     396585             2
# 1  0738700827 1567184960 1567182836 0738700525 07...     168596            12
# 2                                               None    1270652             1
# 3        0842328130 0842330313 0842328610 0842328572     631289             1
# 4        157794349X 0892749504 1577941829 0892749563     455160             0
#
#    AvgRating
# 0        2.0
# 1       12.0
# 2        1.0
# 3        1.0
# 4        0.0

# %% [markdown]
# #### Explore Books

# %% [markdown]
# Dataset contains 392966 book titles.

# %%
# %%time
gdf.shape
# Out:
# CPU times: user 10 µs, sys: 6 µs, total: 16 µs
# Wall time: 23.1 µs
# (392966, 9)

# %% [markdown]
# And all the rows are unique

# %%
# %%time
gdf.ASIN.unique().shape[0]
# Out:
# CPU times: user 3.83 ms, sys: 24.8 ms, total: 28.7 ms
# Wall time: 27.5 ms
# 392966

# %% [markdown]
# This is how the querying can be done.

# %%
# %%time
query = gdf[gdf.ASIN == "1577943082"]
# Out:
# CPU times: user 139 ms, sys: 137 ms, total: 276 ms
# Wall time: 275 ms

# %%
query.to_pandas()
# Out:
#    Id        ASIN                                            Title  \
# 4   5  1577943082  Prayers That Avail Much for Business: Executive
#
#                                           Categories Group  \
# 4  subjects religion prayerbooks devotion worship...  Book
#
#                                    Copurchased  SalesRank  TotalReviews  \
# 4  157794349X 0892749504 1577941829 0892749563     455160             0
#
#    AvgRating
# 4        0.0

# %% [markdown]
# #### Preprocessing

# %% [markdown]
# Convert cudf to Pandas to use the Pandas APIs needed to split (explode) a column into multiple rows

# %%
pd_df = gdf.to_pandas()

# %% [markdown]
# Fill None with empty string for Object Type Columns.

# %%
pd_df.Copurchased = pd_df.Copurchased.fillna('').astype(str)

# %%
pd_df.Categories = pd_df.Categories.fillna('').astype(str)

# %%
pd_df.head(6)
# Out:
#    Id        ASIN                                              Title  \
# 0   1  0827229534            Patterns of Preaching: A Sermon Sampler
# 1   2  0738700797                         Candlemas: Feast of Flames
# 2   3  0486287785   World War II Allied Fighter Planes Trading Cards
# 3   4  0842328327  Life Application Bible Commentary: 1 and 2 Tim...
# 4   5  1577943082    Prayers That Avail Much for Business: Executive
# 5   6  0486220125  How the Other Half Lives: Studies Among the Te...
#
#                                           Categories Group  \
# 0  subjects religion preaching clergy spiritualit...  Book
# 1  subjects witchcraft earth religion based spiri...  Book
# 2  general subjects hobbies home garden crafts books  Book
# 3  subjects life bibles christian general history...  Book
# 4  subjects religion prayerbooks devotion worship...  Book
# 5  general social subjects history jewish nonfict...  Book
#
#                                          Copurchased  SalesRank  TotalReviews  \
# 0  0804215715 156101074X 0687023955 0687074231 08...     396585             2
# 1  0738700827 1567184960 1567182836 0738700525 07...     168596            12
# 2                                                       1270652             1
# 3        0842328130 0842330313 0842328610 0842328572     631289             1
# 4        157794349X 0892749504 1577941829 0892749563     455160             0
# 5        0486401960 0452283612 0486229076 0714840343     188784            17
#
#    AvgRating
# 0        2.0
# 1       12.0
# 2        1.0
# 3        1.0
# 4        0.0
# 5       17.0

# %% [markdown]
# Create new dataframe, splitting books in Copurchased into individual rows with ASIN as the index

# %%
new_pd_df = pd.DataFrame(pd_df.Copurchased.str.split(' ').tolist(), index=pd_df.ASIN).stack()

# %%
new_pd_df.head(6)
# Out:
# ASIN
# 0827229534  0    0804215715
#             1    156101074X
#             2    0687023955
#             3    0687074231
#             4    082721619X
# 0738700797  0    0738700827
# dtype: object

# %%
# get rid of secondary index
# make ASIN as a column (it can't be an index since the values will be duplicate)
new_pd_df = new_pd_df.reset_index([0, 'ASIN'])

# %%
new_pd_df.head()
# Out:
#          ASIN           0
# 0  0827229534  0804215715
# 1  0827229534  156101074X
# 2  0827229534  0687023955
# 3  0827229534  0687074231
# 4  0827229534  082721619X

# %%
# to save memory, select only the columns we need for our graph
# rename column '0' to column 'Copurchase_ASIN'
new_pd_df.columns = ['ASIN', 'Copurchase_ASIN']

# %%
new_pd_df.head(10)
# Out:
#          ASIN Copurchase_ASIN
# 0  0827229534      0804215715
# 1  0827229534      156101074X
# 2  0827229534      0687023955
# 3  0827229534      0687074231
# 4  0827229534      082721619X
# 5  0738700797      0738700827
# 6  0738700797      1567184960
# 7  0738700797      1567182836
# 8  0738700797      0738700525
# 9  0738700797      0738700940

# %%
# %%time
sorted_pd_df = new_pd_df.sort_values(by=['ASIN'])
# Out:
# CPU times: user 1.59 s, sys: 0 ns, total: 1.59 s
# Wall time: 1.59 s

# %%
sorted_pd_df
# Out:
#               ASIN Copurchase_ASIN
# 700446  0000037931
# 511570  0001047655      0061007358
# 511569  0001047655      0061007129
# 511571  0001047655      0061007137
# 511572  0001047655      0061099341
# 511573  0001047655      0061007161
# 886962  0001053388
# 596758  0001053736      0345336062
# 596759  0001053736      0140380531
# 596757  0001053736      0440905605
# 596760  0001053736      0393320979
# 596761  0001053736      0395898714
# 735765  0001053744
# 215665  0001054600
# 683314  0001056298
# 926560  000105709X
# 21250   0001057170      1585673080
# 308118  0001360817
# 168445  0001360841
# 328483  0001360876
# 820167  0001360922
# 482249  0001360965
# 298638  0001469355
# 261472  0001472933      0895403889
# 235146  0001473816
# 2018    0001474103      0001472933
# 2017    0001474103      0895403889
# 180751  0001515195      0005310075
# 180750  0001515195      0875525660
# 91887   0001526626
# ...            ...             ...
# 973798  9999752969
# 299524  9999753256
# 517666  9999766927
# 685337  9999767036
# 466670  9999767044
# 583981  9999767125
# 330349  9999770541
# 388545  9999794971
# 730326  9999803938      091152147X
# 730327  9999803938      088011701X
# 574512  9999804136
# 914641  9999815286
# 612179  9999827659
# 660195  9999829503
# 661931  9999841651
# 317850  9999869491
# 484319  9999878172
# 161649  9999902979
# 869468  9999928498
# 389625  9999928501
# 464215  9999929257
# 599530  9999957501      1573921394
# 599529  9999957501      0879757051
# 599528  9999957501      0553585975
# 599531  9999957501      0553212788
# 599527  9999957501      0451527100
# 861318  9999962017
# 582419  9999974856
# 502784  9999974872
# 350837  9999975380
#
# [1037401 rows x 2 columns]

# %% [markdown]
# Construct Book Graph

# %%
# %%time
new_gdf = cudf.from_pandas(new_pd_df)
# Out:
# CPU times: user 130 ms, sys: 60.2 ms, total: 191 ms
# Wall time: 190 ms

# %%
new_gdf.dtypes
# Out:
# ASIN               object
# Copurchase_ASIN    object
# dtype: object

# %%
combined_gdf = cudf.merge(new_gdf, gdf, on=['ASIN'])

# %%
sorted_combined_gdf = combined_gdf.sort_values(['ASIN'])

# %% [markdown]
# Fill None with empty string for Object Type Columns.

# %%
sorted_combined_gdf['Categories'] = sorted_combined_gdf['Categories'].fillna('')

# %%
sorted_combined_gdf.head().to_pandas()
# Out:
#               ASIN Copurchase_ASIN      Id                        Title  \
# 694075  0000037931                  370379  Saluki Champions, 1952-1988
# 507141  0001047655      0061007129  271961            Prodigal Daughter
# 507145  0001047655      0061007358  271961            Prodigal Daughter
# 507149  0001047655      0061007137  271961            Prodigal Daughter
# 507153  0001047655      0061099341  271961            Prodigal Daughter
#
#                                                Categories Group  \
# 694075                                                     Book
# 507141  general tape subjects literature contemporary ...  Book
# 507145  general tape subjects literature contemporary ...  Book
# 507149  general tape subjects literature contemporary ...  Book
# 507153  general tape subjects literature contemporary ...  Book
#
#                                               Copurchased  SalesRank  \
# 694075                                               None    2031890
# 507141  0061007129 0061007358 0061007137 0061099341 00...    1116690
# 507145  0061007129 0061007358 0061007137 0061099341 00...    1116690
# 507149  0061007129 0061007358 0061007137 0061099341 00...    1116690
# 507153  0061007129 0061007358 0061007137 0061099341 00...    1116690
#
#         TotalReviews  AvgRating
# 694075             0        0.0
# 507141            30       30.0
# 507145            30       30.0
# 507149            30       30.0
# 507153            30       30.0

# %% [markdown]
# Remove Copurchased Columns which is redundant.

# %%
sorted_combined_gdf = sorted_combined_gdf.drop('Copurchased')

# %% [markdown]
# #### Graph

# %% [markdown]
# Calculate Edge Weight (the strength of connection between vertices based on the relative similarity of their neighbors Similarity)

# %% [markdown]
# We will form a graph between ASIN and Copurchase_ASIN. The data we want to use for Graph is Object type. So we will create columns of renumbered source vertex ids and destination vertex ids, both will be int32 type needed by cuGraph. The numbering map from renumbering will map the new ids to original ids. The current renumbering API from cuGraph only support int32 type. So, we need to convert ASIN and Copurchase_ASIN to int32 first.

# %%
sorted_combined_gdf.add_column('ASIN_int', sorted_combined_gdf['ASIN'].astype('int32'))
sorted_combined_gdf.add_column('Copurchase_ASIN_int', sorted_combined_gdf['Copurchase_ASIN'].astype('int32'))

# %%
sorted_combined_gdf.head().to_pandas()
# Out:
#               ASIN Copurchase_ASIN      Id                        Title  \
# 694075  0000037931                  370379  Saluki Champions, 1952-1988
# 507141  0001047655      0061007129  271961            Prodigal Daughter
# 507145  0001047655      0061007358  271961            Prodigal Daughter
# 507149  0001047655      0061007137  271961            Prodigal Daughter
# 507153  0001047655      0061099341  271961            Prodigal Daughter
#
#                                                Categories Group  SalesRank  \
# 694075                                                     Book    2031890
# 507141  general tape subjects literature contemporary ...  Book    1116690
# 507145  general tape subjects literature contemporary ...  Book    1116690
# 507149  general tape subjects literature contemporary ...  Book    1116690
# 507153  general tape subjects literature contemporary ...  Book    1116690
#
#         TotalReviews  AvgRating  ASIN_int  Copurchase_ASIN_int
# 694075             0        0.0     37931                    0
# 507141            30       30.0   1047655             61007129
# 507145            30       30.0   1047655             61007358
# 507149            30       30.0   1047655             61007137
# 507153            30       30.0   1047655             61099341

# %%
sorted_combined_gdf
# Out:
# <cudf.DataFrame ncols=11 nrows=1037401 >

# %%
sorted_combined_gdf.dtypes
# Out:
# ASIN                    object
# Copurchase_ASIN         object
# Id                       int64
# Title                   object
# Categories              object
# Group                   object
# SalesRank                int64
# TotalReviews             int64
# AvgRating              float64
# ASIN_int                 int32
# Copurchase_ASIN_int      int32
# dtype: object

# %%
G = cugraph.Graph()

src_r, dst_r, numbering = G.renumber(sorted_combined_gdf['ASIN_int'], sorted_combined_gdf['Copurchase_ASIN_int'])

# %%
renumbered_map_gdf = cudf.DataFrame()
renumbered_map_gdf.add_column("original_id", numbering)

# %%
sorted_combined_gdf.add_column("src_renumbered", src_r)
sorted_combined_gdf.add_column("dst_renumbered", dst_r)

# %%
sorted_combined_gdf.head(10).to_pandas()
# Out:
#               ASIN Copurchase_ASIN      Id                            Title  \
# 694075  0000037931                  370379      Saluki Champions, 1952-1988
# 507141  0001047655      0061007129  271961                Prodigal Daughter
# 507145  0001047655      0061007358  271961                Prodigal Daughter
# 507149  0001047655      0061007137  271961                Prodigal Daughter
# 507153  0001047655      0061099341  271961                Prodigal Daughter
# 507157  0001047655      0061007161  271961                Prodigal Daughter
# 873449  0001053388                  466894         The Poetry of Lord Byron
# 596387  0001053736      0393320979  316651  Sir Gawain and the Green Knight
# 596391  0001053736      0395898714  316651  Sir Gawain and the Green Knight
# 596405  0001053736      0440905605  316651  Sir Gawain and the Green Knight
#
#                                                Categories Group  SalesRank  \
# 694075                                                     Book    2031890
# 507141  general tape subjects literature contemporary ...  Book    1116690
# 507145  general tape subjects literature contemporary ...  Book    1116690
# 507149  general tape subjects literature contemporary ...  Book    1116690
# 507153  general tape subjects literature contemporary ...  Book    1116690
# 507157  general tape subjects literature contemporary ...  Book    1116690
# 873449  general tape subjects literature authors lord ...  Book    1874503
# 596387  general tape subjects literature short poetry ...  Book      53150
# 596391  general tape subjects literature short poetry ...  Book      53150
# 596405  general tape subjects literature short poetry ...  Book      53150
#
#         TotalReviews  AvgRating  ASIN_int  Copurchase_ASIN_int  \
# 694075             0        0.0     37931                    0
# 507141            30       30.0   1047655             61007129
# 507145            30       30.0   1047655             61007358
# 507149            30       30.0   1047655             61007137
# 507153            30       30.0   1047655             61099341
# 507157            30       30.0   1047655             61007161
# 873449             0        0.0   1053388                    0
# 596387            15       15.0   1053736            393320979
# 596391            15       15.0   1053736            395898714
# 596405            15       15.0   1053736            440905605
#
#         src_renumbered  dst_renumbered
# 694075          247725               0
# 507141          354701           26322
# 507145          354701           37041
# 507149          354701           26683
# 507153          354701          126539
# 507157          354701           27795
# 873449          236861               0
# 596387          253550          265651
# 596391          253550          147791
# 596405          253550           21474

# %%
sorted_combined_gdf.dtypes
# Out:
# ASIN                    object
# Copurchase_ASIN         object
# Id                       int64
# Title                   object
# Categories              object
# Group                   object
# SalesRank                int64
# TotalReviews             int64
# AvgRating              float64
# ASIN_int                 int32
# Copurchase_ASIN_int      int32
# src_renumbered           int32
# dst_renumbered           int32
# dtype: object

# %%
for i in range(10):
    print(" " + str(i) +
          ": (" + str(sorted_combined_gdf.ASIN_int[i]) + "," + 
          str(sorted_combined_gdf.Copurchase_ASIN_int[i]) +")"
          ", renumbered: (" + str(sorted_combined_gdf.src_renumbered[i]) + "," + 
          str(sorted_combined_gdf.dst_renumbered[i]) +")"
          ", translate back: (" + str(numbering[sorted_combined_gdf.src_renumbered[i]]) + "," +
          str(numbering[sorted_combined_gdf.dst_renumbered[i]]) +")"
         )
# Out:
#  0: (37931,0), renumbered: (247725,0), translate back: (37931,0)
#  1: (1047655,61007129), renumbered: (354701,26322), translate back: (1047655,61007129)
#  2: (1047655,61007358), renumbered: (354701,37041), translate back: (1047655,61007358)
#  3: (1047655,61007137), renumbered: (354701,26683), translate back: (1047655,61007137)
#  4: (1047655,61099341), renumbered: (354701,126539), translate back: (1047655,61099341)
#  5: (1047655,61007161), renumbered: (354701,27795), translate back: (1047655,61007161)
#  6: (1053388,0), renumbered: (236861,0), translate back: (1053388,0)
#  7: (1053736,393320979), renumbered: (253550,265651), translate back: (1053736,393320979)
#  8: (1053736,395898714), renumbered: (253550,147791), translate back: (1053736,395898714)
#  9: (1053736,440905605), renumbered: (253550,21474), translate back: (1053736,440905605)

# %%
def mapping_to_original(gdf):
    for i in range(len(gdf)-1):
        print(" " + str(i) +
              ": (" + str(gdf.ASIN_int[i]) + "," + 
              str(gdf.Copurchase_ASIN_int[i]) +")"
              ", renumbered: (" + str(gdf.src_renumbered[i]) + "," + 
              str(gdf.dst_renumbered[i]) +")"
              ", translate back: (" + str(numbering[gdf.src_renumbered[i]]) + "," +
              str(numbering[gdf.dst_renumbered[i]]) +")"
             )

# %%
query_1 = sorted_combined_gdf[sorted_combined_gdf.src_renumbered == 108718]
query_2 = sorted_combined_gdf[sorted_combined_gdf.src_renumbered == 160]

# %%
query_1.to_pandas()
# Out:
#               ASIN Copurchase_ASIN      Id      Title  \
# 220416  0425164349      0385334206  125240  Timequake
# 220420  0425164349      0385333498  125240  Timequake
# 220424  0425164349      038533348X  125240  Timequake
# 220428  0425164349      0385333501  125240  Timequake
# 223679  0425164349      0425130215  125240  Timequake
#
#                                                Categories Group  SalesRank  \
# 220416  general science subjects literature fantasy au...  Book      20867
# 220420  general science subjects literature fantasy au...  Book      20867
# 220424  general science subjects literature fantasy au...  Book      20867
# 220428  general science subjects literature fantasy au...  Book      20867
# 223679  general science subjects literature fantasy au...  Book      20867
#
#         TotalReviews  AvgRating   ASIN_int  Copurchase_ASIN_int  \
# 220416           176      176.0  425164349            385334206
# 220420           176      176.0  425164349            385333498
# 220424           176      176.0  425164349             38533348
# 220428           176      176.0  425164349            385333501
# 223679           176      176.0  425164349            425130215
#
#         src_renumbered  dst_renumbered
# 220416          108718          239424
# 220420          108718          205098
# 220424          108718          136798
# 220428          108718          205265
# 223679          108718           43672

# %%
query_2.to_pandas()
# Out:
#               ASIN Copurchase_ASIN      Id                    Title  \
# 811651  0899683061      0385333498  415390  Venus on the Half-Shell
# 811655  0899683061      0899667570  415390  Venus on the Half-Shell
# 811659  0899683061      0425164349  415390  Venus on the Half-Shell
# 811663  0899683061      038533348X  415390  Venus on the Half-Shell
# 811677  0899683061      0743422007  415390  Venus on the Half-Shell
#
#                                             Categories Group  SalesRank  \
# 811651  fantasy science subjects general fiction books  Book     104045
# 811655  fantasy science subjects general fiction books  Book     104045
# 811659  fantasy science subjects general fiction books  Book     104045
# 811663  fantasy science subjects general fiction books  Book     104045
# 811677  fantasy science subjects general fiction books  Book     104045
#
#         TotalReviews  AvgRating   ASIN_int  Copurchase_ASIN_int  \
# 811651            39       39.0  899683061            385333498
# 811655            39       39.0  899683061            899667570
# 811659            39       39.0  899683061            425164349
# 811663            39       39.0  899683061             38533348
# 811677            39       39.0  899683061            743422007
#
#         src_renumbered  dst_renumbered
# 811651             160          205098
# 811655             160           41952
# 811659             160          108718
# 811663             160          136798
# 811677             160          328148

# %% [markdown]
# Create a Directed Graph of a copurchase network. Edges are pointing from one book to another. Interpretation is when the user purchase 'src_renumbered', this will influence the 'dst_renumbered' book to be purchased. Since this is a unipartite graph, the similarity coefficient between source and destination is calculated based on the number of neighbor nodes that both source and destination shared.

# %%
graph = cugraph.Graph()
graph.add_edge_list(sorted_combined_gdf["src_renumbered"], sorted_combined_gdf["dst_renumbered"])

# %%
# %time jac_df = cugraph.jaccard(graph)
# Out:
# CPU times: user 6.69 ms, sys: 13.7 ms, total: 20.3 ms
# Wall time: 19.2 ms

# %%
jac_df
# Out:
# <cudf.DataFrame ncols=3 nrows=1037401 >

# %%
graph.number_of_edges()
# Out:
# 1037401

# %%
graph.number_of_vertices()
# Out:
# 392970

# %%
degree = graph.degree()

# %%
in_degree = graph.in_degree()

# %%
out_degree = graph.out_degree()

# %%
degree_query = degree[degree.vertex == 160]
in_degree_query = in_degree[in_degree.vertex == 160]
out_degree_query = out_degree[out_degree.vertex == 160]

# %%
degree_query.to_pandas()
# Out:
#      vertex  degree
# 160     160       5

# %%
in_degree_query.to_pandas()
# Out:
#      vertex  degree
# 160     160       0

# %%
out_degree_query.to_pandas()
# Out:
#      vertex  degree
# 160     160       5

# %%
jac_query_1 = jac_df[jac_df.source == 2]
jac_query_2 = jac_df[jac_df.destination == 13578]

# %%
jac_query_1.to_pandas()
# Out:
#    source  destination  jaccard_coeff
# 1       2         1768            0.0
# 2       2       175960            0.0

# %%
jac_query_2.to_pandas()
# Out:
#         source  destination  jaccard_coeff
# 4675      1768        13578       0.000000
# 143983   54703        13578       0.166667
# 198538   75315        13578       0.400000
# 206705   78331        13578       0.250000
# 224889   85144        13578       0.000000
# 293393  111290        13578       0.400000
# 323422  122522        13578       0.166667
# 463344  175115        13578       0.166667
# 989152  374721        13578       0.000000

# %% [markdown]
# Query Jaccard Coefficient between 0.1 and 0.3

# %%
jac_count_query = jac_df[jac_df.jaccard_coeff < 0.3]
final_query = jac_count_query[jac_count_query.jaccard_coeff > 0.1]

# %%
final_query.to_pandas()
final_query.sort_values("jaccard_coeff", ascending=True).to_pandas()
# Out:
#          source  destination  jaccard_coeff
# 65           19       357871       0.111111
# 95           31        22716       0.111111
# 98           31       251997       0.111111
# 110          36       362777       0.111111
# 147          54       215276       0.111111
# 170          62       258634       0.111111
# 298         112        25001       0.111111
# 411         160        41952       0.111111
# 413         160       136798       0.111111
# 414         160       205098       0.111111
# 415         160       328148       0.111111
# 428         166        55173       0.111111
# 429         166       173290       0.111111
# 466         181       132006       0.111111
# 478         184       319507       0.111111
# 500         190        23711       0.111111
# 619         238         1789       0.111111
# 638         243       289603       0.111111
# 716         280         2573       0.111111
# 719         280       264904       0.111111
# 722         282        50169       0.111111
# 725         282       379138       0.111111
# 793         308       180269       0.111111
# 796         308       363119       0.111111
# 804         312       172954       0.111111
# 808         312       361535       0.111111
# 814         315         1694       0.111111
# 815         315        62552       0.111111
# 816         315       180082       0.111111
# 817         315       305882       0.111111
# ...         ...          ...            ...
# 1036522  392636       392894       0.285714
# 1036533  392641       314235       0.285714
# 1036587  392660        31339       0.285714
# 1036618  392670       227484       0.285714
# 1036633  392675       173439       0.285714
# 1036660  392685       129027       0.285714
# 1036663  392685       332226       0.285714
# 1036744  392715        48183       0.285714
# 1036770  392724       339137       0.285714
# 1036811  392743        14610       0.285714
# 1036814  392743       275926       0.285714
# 1036824  392746       201042       0.285714
# 1036901  392776       104160       0.285714
# 1036953  392795       367787       0.285714
# 1036992  392809       181013       0.285714
# 1036996  392811       202215       0.285714
# 1037006  392813       279764       0.285714
# 1037013  392817       168076       0.285714
# 1037017  392818       275722       0.285714
# 1037018  392818       299122       0.285714
# 1037049  392829       109964       0.285714
# 1037082  392843         3888       0.285714
# 1037084  392843       256897       0.285714
# 1037155  392873        32926       0.285714
# 1037156  392873       143552       0.285714
# 1037158  392873       351977       0.285714
# 1037183  392884         9193       0.285714
# 1037210  392892         9193       0.285714
# 1037295  392926       246334       0.285714
# 1037296  392926       301471       0.285714
#
# [347319 rows x 3 columns]

# %% [markdown]
# two_hop = graph.get_two_hop_neighbors()

# %%
two_hop.to_pandas()
# Out:
#           first  second
# 0             2   13578
# 1             2   31899
# 2             2  154112
# 3             2  212003
# 4             2  218064
# 5             2  340652
# 6             3    9829
# 7             3   35350
# 8             3   69979
# 9             3   81636
# 10            3  183197
# 11            3  234316
# 12            3  249409
# 13            3  257401
# 14            3  299955
# 15            3  328301
# 16            3  332369
# 17            3  335216
# 18            3  386693
# 19            4     826
# 20            4   15976
# 21            4   95630
# 22            4  251738
# 23            4  306933
# 24            4  346395
# 25            6   24893
# 26            6   35378
# 27            6   66820
# 28            6   73270
# 29            6   78965
# ...         ...     ...
# 2176932  392962  170920
# 2176933  392962  220554
# 2176934  392962  231117
# 2176935  392962  234633
# 2176936  392962  235940
# 2176937  392962  236211
# 2176938  392962  300788
# 2176939  392962  380280
# 2176940  392963   55814
# 2176941  392963  137350
# 2176942  392963  244341
# 2176943  392963  257619
# 2176944  392963  377516
# 2176945  392963  377751
# 2176946  392966  105395
# 2176947  392966  155651
# 2176948  392966  286574
# 2176949  392966  369290
# 2176950  392967   11359
# 2176951  392967  141899
# 2176952  392967  143147
# 2176953  392967  153836
# 2176954  392967  171045
# 2176955  392967  171363
# 2176956  392967  192409
# 2176957  392967  201336
# 2176958  392967  241290
# 2176959  392967  299590
# 2176960  392967  343767
# 2176961  392967  354285
#
# [2176962 rows x 2 columns]

# %%
two_hop_query = two_hop[two_hop.first == 2]
# Out:
#    first  second
# 0      2   13578
# 1      2   31899
# 2      2  154112
# 3      2  212003
# 4      2  218064

# %%
new_query = sorted_combined_gdf[sorted_combined_gdf.dst_renumbered == 31899]

# %%
new_query.to_pandas()
# Out:
#               ASIN Copurchase_ASIN      Id  \
# 740368  0060506539      1563384086  391724
# 906298  0060556102      1563384086  482724
# 543799  1563383624      1563384086  292054
# 376103  157075134X      1563384086  203476
# 246589  1570753857      1563384086  137358
#
#                                                     Title  \
# 740368                         When Religion Becomes Evil
# 906298     When Religion Becomes Evil: Five Warning Signs
# 543799  Jesus Against Christianity: Reclaiming the Mis...
# 376103  School of Assassins: The Case for Closing the ...
# 246589  School of Assassins: Guns, Greed, and Globaliz...
#
#                                                Categories Group  SalesRank  \
# 740368  subjects comparative religion spirituality soc...  Book     203685
# 906298  subjects comparative religion spirituality soc...  Book      40349
# 543799  reference subjects christology religion theolo...  Book     192034
# 376103  social general subjects nonfiction sciences so...  Book     884968
# 246589  events social subjects general terrorism nonfi...  Book     376163
#
#         TotalReviews  AvgRating    ASIN_int  Copurchase_ASIN_int  \
# 740368            25       25.0    60506539           1563384086
# 906298            25       25.0    60556102           1563384086
# 543799             6        6.0  1563383624           1563384086
# 376103             6        6.0   157075134           1563384086
# 246589             6        6.0  1570753857           1563384086
#
#         src_renumbered  dst_renumbered
# 740368          374721           31899
# 906298            1768           31899
# 543799           10303           31899
# 376103          216607           31899
# 246589          323191           31899

# %%
query_1 = sorted_combined_gdf[sorted_combined_gdf.src_renumbered == 2]

# %%
query_1.to_pandas()
# Out:
#               ASIN Copurchase_ASIN      Id  \
# 720259  077880027X      0778800482  388677
# 720263  077880027X      0965260313  388677
# 720267  077880027X      0671750194  388677
# 720271  077880027X      0553380907  388677
# 720275  077880027X      1579547222  388677
#
#                                                     Title  \
# 720259  Better Baby Food: Your Essential Guide to Nutr...
# 720263  Better Baby Food: Your Essential Guide to Nutr...
# 720267  Better Baby Food: Your Essential Guide to Nutr...
# 720271  Better Baby Food: Your Essential Guide to Nutr...
# 720275  Better Baby Food: Your Essential Guide to Nutr...
#
#                                                Categories Group  SalesRank  \
# 720259  general parenting subjects body wine medicine ...  Book     130103
# 720263  general parenting subjects body wine medicine ...  Book     130103
# 720267  general parenting subjects body wine medicine ...  Book     130103
# 720271  general parenting subjects body wine medicine ...  Book     130103
# 720275  general parenting subjects body wine medicine ...  Book     130103
#
#         TotalReviews  AvgRating  ASIN_int  Copurchase_ASIN_int  \
# 720259            15       15.0  77880027            778800482
# 720263            15       15.0  77880027            965260313
# 720267            15       15.0  77880027            671750194
# 720271            15       15.0  77880027            553380907
# 720275            15       15.0  77880027           1579547222
#
#         src_renumbered  dst_renumbered
# 720259          392926            9537
# 720263          392926            5139
# 720267          392926          301471
# 720271          392926          246334
# 720275          392926          141142

# %%
two_hop_query.to_pandas()
# Out:
#    first  second
# 0      2   13578
# 1      2   31899
# 2      2  154112
# 3      2  212003
# 4      2  218064
# 5      2  340652

# %%
rows = sorted_combined_gdf[sorted_combined_gdf.ASIN_int == 77880027]
rows.to_pandas()
# Out:
#               ASIN Copurchase_ASIN      Id  \
# 720259  077880027X      0778800482  388677
# 720263  077880027X      0965260313  388677
# 720267  077880027X      0671750194  388677
# 720271  077880027X      0553380907  388677
# 720275  077880027X      1579547222  388677
#
#                                                     Title  \
# 720259  Better Baby Food: Your Essential Guide to Nutr...
# 720263  Better Baby Food: Your Essential Guide to Nutr...
# 720267  Better Baby Food: Your Essential Guide to Nutr...
# 720271  Better Baby Food: Your Essential Guide to Nutr...
# 720275  Better Baby Food: Your Essential Guide to Nutr...
#
#                                                Categories Group  SalesRank  \
# 720259  general parenting subjects body wine medicine ...  Book     130103
# 720263  general parenting subjects body wine medicine ...  Book     130103
# 720267  general parenting subjects body wine medicine ...  Book     130103
# 720271  general parenting subjects body wine medicine ...  Book     130103
# 720275  general parenting subjects body wine medicine ...  Book     130103
#
#         TotalReviews  AvgRating  ASIN_int  Copurchase_ASIN_int  \
# 720259            15       15.0  77880027            778800482
# 720263            15       15.0  77880027            965260313
# 720267            15       15.0  77880027            671750194
# 720271            15       15.0  77880027            553380907
# 720275            15       15.0  77880027           1579547222
#
#         src_renumbered  dst_renumbered
# 720259          392926            9537
# 720263          392926            5139
# 720267          392926          301471
# 720271          392926          246334
# 720275          392926          141142

# %% [markdown]
# Get renumbered id of ASIN_int

# %%
ASIN = '077880027X'
ASIN_int = 77880027
renum_ASIN = numbering[numbering == ASIN_int].index[0]

# %%
jac_df.sort_values("jaccard_coeff", ascending=False).to_pandas()

# %%
# %%time
edge_ls = cudf.DataFrame()
edge_ls["second"] = two_hop.second.unique().astype("int32")
# Out:
# CPU times: user 278 ms, sys: 9.48 ms, total: 288 ms
# Wall time: 287 ms

# %%
# %%time
edge_ls["first"] = renum_ASIN.astype("int32")
# Out:
# CPU times: user 214 ms, sys: 8.31 ms, total: 222 ms
# Wall time: 220 ms

# %%
# %%time
edge_ls.sort_values("second", ascending=False).head().to_pandas()
# Out:
# CPU times: user 8.08 ms, sys: 16 ms, total: 24.1 ms
# Wall time: 22.8 ms
#         second   first
# 145383  392963  392926
# 145382  392962  392926
# 145381  392960  392926
# 145380  392954  392926
# 145379  392952  392926

# %%
# %%time
jacc = cugraph.jaccard(graph, first=edge_ls.first, second=edge_ls.second)
# Out:
# CPU times: user 5.23 ms, sys: 593 µs, total: 5.82 ms
# Wall time: 4.85 ms

# %% [markdown]
# Sorting by descending order of Jaccard Coefficient to see the most similar book.

# %%
# %%time
jacc.sort_values("jaccard_coeff", ascending=False).head(15).to_pandas()
# Out:
# CPU times: user 20.1 ms, sys: 12.1 ms, total: 32.2 ms
# Wall time: 31 ms
#         source  destination  jaccard_coeff
# 145369  392926       392926       1.000000
# 122993  392926       332769       0.500000
# 12941   392926        35293       0.285714
# 91078   392926       246334       0.285714
# 111407  392926       301471       0.285714
# 139332  392926       376868       0.285714
# 31412   392926        85045       0.250000
# 42625   392926       115568       0.250000
# 55881   392926       151095       0.250000
# 16836   392926        45871       0.125000
# 21937   392926        59619       0.125000
# 39602   392926       107416       0.125000
# 41673   392926       112995       0.125000
# 52212   392926       141142       0.125000
# 56233   392926       152064       0.125000

# %% [markdown]
# Sample 3 books in subgraph related to book's renum_ASIN 392926

# %%
ASIN = '077880027X'
ASIN_int = 77880027
renum_ASIN = numbering[numbering == ASIN_int].index[0]
renum_ASIN
# Out:
# 392926

# %%
ASIN_int_1 = numbering[392926]
ASIN_int_1
# Out:
# 77880027

# %%
book_title = sorted_combined_gdf[sorted_combined_gdf.ASIN_int == ASIN_int_1].Title.unique()
book_cats = sorted_combined_gdf[sorted_combined_gdf.ASIN_int == ASIN_int_1].Categories.unique()
book_cats_ls_1 = book_cats.str.split()

print(book_title)
book_cats_ls_1.to_pandas()
# Out:
# 0    Better Baby Food: Your Essential Guide to Nutrition, Feeding & Cooking for Your Baby & Toddler
# Name: Title, dtype: object
#         0          1         2     3     4         5         6        7   \
# 0  general  parenting  subjects  body  wine  medicine  families  medical
#
#        8       9          10    11       12    13        14         15  \
# 0  health  babies  technical  food  cooking  mind  toddlers  nutrition
#
#         16     17            18
# 0  nursing  books  professional

# %% [markdown]
# Get ASIN_int from numbering mapping

# %%
ASIN_int_2 = numbering[332769]
ASIN_int_2
# Out:
# 789471906

# %%
book_title = sorted_combined_gdf[sorted_combined_gdf.ASIN_int == ASIN_int_2].Title.unique()
book_cats = sorted_combined_gdf[sorted_combined_gdf.ASIN_int == ASIN_int_2].Categories.unique()
book_cats_ls_2 = book_cats.str.split()

print(book_title)
book_cats_ls_2.to_pandas()
# Out:
# 0    Organic Baby and Toddler Cookbook (Organic)
# Name: Title, dtype: object
# 0    general reference subjects healthy wine parenting families special vegetables health food cooking nutrition diet books vegetarian
# Name: Categories, dtype: object
#         0          1         2        3     4          5         6        7   \
# 0  general  reference  subjects  healthy  wine  parenting  families  special
#
#            8       9     10       11         12    13     14          15
# 0  vegetables  health  food  cooking  nutrition  diet  books  vegetarian

# %%
ASIN_int_3 = numbering[152064]
ASIN_int_3
# Out:
# 71387765

# %%
book_title = sorted_combined_gdf[sorted_combined_gdf.ASIN_int == ASIN_int_3].Title.unique()
book_cats = sorted_combined_gdf[sorted_combined_gdf.ASIN_int == ASIN_int_3].Categories.unique()
book_cats_ls_3 = book_cats.str.split()

print(book_title)
book_cats_ls_3.to_pandas()
# Out:
# 0    Baby Signs: How to Talk with Your Baby Before Your Baby Can Talk, New Edition
# Name: Title, dtype: object
#         0     1         2        3       4          5        6            7   \
# 0  general  body  subjects  parents  infant  parenting  infants  development
#
#          8       9       10     11         12          13      14        15  \
# 0  families  health  babies  music  specialty  counseling  videos  toddlers
#
#            16    17      18     19
# 0  psychology  mind  stores  books

# %%
def find_common_categories(A,B):
    for i in A:
        for j in B:
            if (A[i][0] == B[j][0]): 
                print(A[i][0], end = " ")

# %%
find_common_categories(book_cats_ls_1, book_cats_ls_3)
# Out:
# general parenting subjects body families health babies mind toddlers books
